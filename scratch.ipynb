# %%
# %run -i 'siglip.py'

# %%
from torchview import draw_graph
import graphviz
from siglip import SiglipVisionTransformer, SiglipVisionConfig

model = SiglipVisionTransformer(config=SiglipVisionConfig())
batch_size = 2

model_graph = draw_graph(model, input_size=(batch_size, 3, 224, 224), device='cpu')
model_graph.visual_graph

# %%
# %run -i 'proc_paligemma.py'
